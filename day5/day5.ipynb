# %% [markdown]
# # Day 5: Binary Boarding
#
# [Brief](https://adventofcode.com/2020/day/5)
#
# - `F` - front
# - `B` - back
# - `L` - left
# - `R` - right
# - 128 rows (0 to 127)
# - 8 seats per row (0 to 7)

# %%
# end will be the number of rows (127) or columns (7)
# lower_char is the character that tells us to keep the lower half of the range
# upper_char is the character that tells us to keep the upper half of the range
# lower is whether the result should be the lower value of the range or higher value
# this is a little bit like a binary search
def binary_space_partitioning(chars, end, lower_char="F", upper_char="B", lower=True):
    start = 0
    
    # go through each of the characters
    for char in chars:
        # calculate the midpoint between the start and end positions
        mid = (start + end) // 2
        if char == lower_char:
            # if the character is equal to the lower_char (e.g. F), keep the lower half
            end = mid
        elif char == upper_char:
            # if the character is equal to the upper_char (e.g. B), keep the higher half
            start = mid + 1
    
    if lower:
        return start
    else:
        return end

def get_seat(chars):
    # calculate the row
    row = binary_space_partitioning(chars[0:7], 127, "F", "B", True)
    col = binary_space_partitioning(chars[7:], 7, "L", "R", False)  
    seat = (row * 8) + col
    
    return (seat, row, col)

# %%
assert get_seat("FBFBBFFRLR") == (357, 44, 5)

assert get_seat("BFFFBBFRRR") == (567, 70, 7)
assert get_seat("FFFBBBFRRR") == (119, 14, 7)
assert get_seat("BBFFBBFRLL") == (820, 102, 4)

# %% [markdown]
# ## Part 1

# %%
with open("input.txt", "r") as file:
    boarding_passes = file.read().splitlines()

highest = -1
for boarding_pass in boarding_passes:
    seat, row, col = get_seat(boarding_pass)
    if seat > highest:
        highest = seat

print("The highest seat ID is {}".format(highest))
# Out:
# The highest seat ID is 871

# %% [markdown]
# ## Part 2
#
# Finding free seats from the list

# %%
import numpy as np

all_seats = np.zeros((128, 8))
for boarding_pass in boarding_passes:
    seat, row, col = get_seat(boarding_pass)
    all_seats[row][col] = 1

free_seats = np.argwhere(all_seats == 0)
for seat in free_seats:
    seat_id = (seat[0] * 8) + seat[1]
    print("Free seat ID {} at {}, {}".format(seat_id, seat[0], seat[1]))
# Out:
# Free seat ID 0 at 0, 0
# Free seat ID 1 at 0, 1
# Free seat ID 2 at 0, 2
# Free seat ID 3 at 0, 3
# Free seat ID 4 at 0, 4
# Free seat ID 5 at 0, 5
# Free seat ID 6 at 0, 6
# Free seat ID 7 at 0, 7
# Free seat ID 8 at 1, 0
# Free seat ID 9 at 1, 1
# Free seat ID 10 at 1, 2
# Free seat ID 11 at 1, 3
# Free seat ID 640 at 80, 0
# Free seat ID 872 at 109, 0
# Free seat ID 873 at 109, 1
# Free seat ID 874 at 109, 2
# Free seat ID 875 at 109, 3
# Free seat ID 952 at 119, 0
# Free seat ID 953 at 119, 1
# Free seat ID 954 at 119, 2
# Free seat ID 955 at 119, 3
# Free seat ID 956 at 119, 4
# Free seat ID 957 at 119, 5
# Free seat ID 958 at 119, 6
# Free seat ID 959 at 119, 7
# Free seat ID 960 at 120, 0
# Free seat ID 961 at 120, 1
# Free seat ID 962 at 120, 2
# Free seat ID 963 at 120, 3
# Free seat ID 964 at 120, 4
# Free seat ID 965 at 120, 5
# Free seat ID 966 at 120, 6
# Free seat ID 967 at 120, 7
# Free seat ID 968 at 121, 0
# Free seat ID 969 at 121, 1
# Free seat ID 970 at 121, 2
# Free seat ID 971 at 121, 3
# Free seat ID 972 at 121, 4
# Free seat ID 973 at 121, 5
# Free seat ID 974 at 121, 6
# Free seat ID 975 at 121, 7
# Free seat ID 976 at 122, 0
# Free seat ID 977 at 122, 1
# Free seat ID 978 at 122, 2
# Free seat ID 979 at 122, 3
# Free seat ID 980 at 122, 4
# Free seat ID 981 at 122, 5
# Free seat ID 982 at 122, 6
# Free seat ID 983 at 122, 7
# Free seat ID 984 at 123, 0
# Free seat ID 985 at 123, 1
# Free seat ID 986 at 123, 2
# Free seat ID 987 at 123, 3
# Free seat ID 988 at 123, 4
# Free seat ID 989 at 123, 5
# Free seat ID 990 at 123, 6
# Free seat ID 991 at 123, 7
# Free seat ID 992 at 124, 0
# Free seat ID 993 at 124, 1
# Free seat ID 994 at 124, 2
# Free seat ID 995 at 124, 3
# Free seat ID 996 at 124, 4
# Free seat ID 997 at 124, 5
# Free seat ID 998 at 124, 6
# Free seat ID 999 at 124, 7
# Free seat ID 1000 at 125, 0
# Free seat ID 1001 at 125, 1
# Free seat ID 1002 at 125, 2
# Free seat ID 1003 at 125, 3
# Free seat ID 1004 at 125, 4
# Free seat ID 1005 at 125, 5
# Free seat ID 1006 at 125, 6
# Free seat ID 1007 at 125, 7
# Free seat ID 1008 at 126, 0
# Free seat ID 1009 at 126, 1
# Free seat ID 1010 at 126, 2
# Free seat ID 1011 at 126, 3
# Free seat ID 1012 at 126, 4
# Free seat ID 1013 at 126, 5
# Free seat ID 1014 at 126, 6
# Free seat ID 1015 at 126, 7
# Free seat ID 1016 at 127, 0
# Free seat ID 1017 at 127, 1
# Free seat ID 1018 at 127, 2
# Free seat ID 1019 at 127, 3
# Free seat ID 1020 at 127, 4
# Free seat ID 1021 at 127, 5
# Free seat ID 1022 at 127, 6
# Free seat ID 1023 at 127, 7

# %% [markdown]
# The puzzle says that the seat is not at the very front or back, the only seat that is near the middle is **640**!
